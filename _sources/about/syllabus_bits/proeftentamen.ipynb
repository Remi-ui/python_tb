# %% [markdown]
# # Proeftentamen

# %% [markdown]
# ## Vraag 1

# %%
items = [2, "pen", 4.5, "notebook", 2]

# %% [markdown]
# Gegeven de bovenstaande code, schrijf hieronder een for-loop waarmee elk datatype geprint kan worden.

# %%
# Schrijf hier je for-loop

# %% [markdown]
# Wat is de output van `print(len(items))` ?

# %%
# Schrijf hier je antwoord (eventueel met code)

# %% [markdown]
# Hoeveel items in de lijst zijn van het type string?

# %% [markdown]
# _Typ hier je uitleg._

# %% [markdown]
# ## Vraag 2

# %%
def contains(word):
  vowels="aeiou"
  for letter in word:
    if letter in vowels:
      print(True)
    else:
      print(False)

contains("towels")

# %% [markdown]
# Wat is de uitkomst van de bovenstaande code? Leg hierbij uit hoe je tot je antwoord gekomen bent.

# %% [markdown]
# _Typ hier je uitleg._

# %% [markdown]
# Wat is de uitkomst bij `contains_vowels("cookies")` ? Leg hierbij uit hoe je tot het antwoord gekomen bent.

# %% [markdown]
# _Typ hier je uitleg._

# %% [markdown]
# ## Vraag 3

# %%
fruit_lijst = ["appel", "banaan", "peer", "kers", "aardbei"]

# %% [markdown]
# Schrijf de code waarmee een zesde stuk fruit kan worden toegevoegd aan de bovenstaande lijst.

# %%
# Schrijf hier je code

# %% [markdown]
# Schrijf de code waarmee het eerste item uit de lijst kan worden geprint.

# %%
# Schrijf hier je code

# %% [markdown]
# Van welk datatype zijn de items in de lijst?

# %% [markdown]
# _Typ hier je antwoord._
