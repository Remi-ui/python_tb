# %% [markdown]
# # Oefening data verkennen met Python
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1Um-GPGYF_XweLkbz-LyNJ8gjmTNZ2e8V?usp=sharing)
#
# **Duur:** ± 20 minuten
#
#
# **Dit is geen weekopdracht, deze opdracht wordt uitgevoerd tijdens de les in week 5.**

# %% [markdown]
# ## 🪜 Stap 1 – Voorbereiding
#
# Importeer de pandas-library en laad een kleine dataset.

# %%
# Stap 1: Importeer pandas
# (Tip: gebruik 'import pandas as pd')

# Via bijvoorbeeld Stackoverflow is te vinden hoe je een dataset kan inladen via een URL. Zoek dit op en laad het volgende dataset in:
# https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv

# Toon de eerste paar rijen van de dataset met de method .head()

# %% [markdown]
# ## 🔍 Stap 2 – Verken de data
#
# Bekijk de dataset om te begrijpen hoe deze is opgebouwd. Gebruik ook hiervoor zeker het internet.

# %%
# Stap 2: Verken de dataset
# Print de vorm (shape) van de dataset
# Print de kolomnamen
# Toon basisstatistieken met describe()

# %% [markdown]
# ## 🧾 Stap 3 – Eenvoudige analyse
#
# Beantwoord een paar vragen over de data.

# %%
# Stap 3: Analyseer de data

# Hoeveel rijen bevatten missende waarden?

# Wat is de gemiddelde 'total_bill'?

# %% [markdown]
# ## 🍽️ Stap 4 – Filteren en groeperen
#
# Gebruik `groupby()` om de data tussen groepen te vergelijken.

# %%
# Stap 4: Filteren en groeperen
# Bereken de gemiddelde fooi per dag
# Welke dag heeft de hoogste gemiddelde fooi?

# %% [markdown]
# ## 📊 Stap 5 – (Optioneel) Visualiseren
#
# Maak een eenvoudige staafgrafiek van de gemiddelde fooi per dag. Gebruik hiervoor bijvoorbeeld Seaborn of Matplotlib.

# %%
# Stap 5: Eenvoudige visualisatie
# (Tip: gebruik avg_tips.plot(kind="bar"))

# %% [markdown]
# ---
#
# ### 💬 Bespreekvragen
# 1. Welke kolom bevat de meeste missende waarden?
# 2. Wat doet de `groupby()`-functie precies?
# 3. Hoe kun je onderzoeken of **geslacht** of **rokerstatus** invloed heeft op de hoogte van de fooi?
#
# ---
#
# **Tip:** Als je eerder klaar bent, probeer dan `"day"` te vervangen door `"sex"` of `"smoker"` in de `groupby()`-code en bekijk wat er verandert!
